# %%
import pandas

path = "C:/users/clari/downloads/animals/"
animal_types = ['mammals', 'reptiles', 'amphibians', 'birds', 'insects', 'mollusks']
csv_ext = ".csv"

# %%
def read_animal_csv(animal_type):
    csv_file = path + animal_type + csv_ext
    df = pandas.read_csv(csv_file)
    df['Scientific Name'] = df['Scientific Name'].apply(lambda name: name.replace(' ', '_'))
    return df

# %%
read_animal_csv('mammals')
# Out:
#                  Common Name          Scientific Name
# 0      Western Gray Squirrel          Sciurus_griseus
# 1       Eastern Fox Squirrel            Sciurus_niger
# 2      Eastern Gray Squirrel     Sciurus_carolinensis
# 3         Eastern Cottontail    Sylvilagus_floridanus
# 4          Desert Cottontail     Sylvilagus_audubonii
# 5   Californian brush rabbit      Sylvilagus_bachmani
# 6                     Coyote            Canis_latrans
# 7               Domestic Cat              Felis_catus
# 8                     Bobcat               Lynx_rufus
# 9                  Black Rat            Rattus_rattus
# 10             Pocket Gopher          Thomomys_bottae
# 11                Common Dog         Canis_familiaris
# 12                      Wolf              Canis_lupus
# 13                     Horse           Equus_caballus
# 14                    Donkey             Equus_asinus
# 15                       Cow               Bos_taurus
# 16                       Pig           Sus_domesticus
# 17                      Goat             Capra_hircus
# 18                     Sheep               Ovis_aries
# 19       American Black Bear         Ursus_americanus
# 20              Grizzly Bear             Ursus_arctos
# 21                   Raccoon            Procyon_lotor
# 22      California mule deer  Odocoileus_californicus
# 23                     Skunk        Mephitis_mephitis
# 24                   Opossum     Didelphis_virginiana
# 25                   Red Fox            Vulpes_vulpes
# 26             Mountian lion            Puma_concolor
